# %% [markdown]
# <a href="https://colab.research.google.com/github/mishabali535-cell/ict_assignments/blob/main/assignment01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Grocery Billing

# %%
a=int(input("enter the name of item 1 :  "))
b=int(input("quantity of item 2 :  "))
c=int(input("enter the name of item 3 :  "))
d=int(input("quantity of item 4 :  "))
item1=a*b
item2=c*d
sum=item1+item2
print("total amount is :  ",sum)
# Out:
# enter the name of item 1 :  45
# quantity of item 2 :  3
# enter the name of item 3 :  30
# quantity of item 4 :  2
# total amount is :   195

# %%
#Temperature Conversion

# %%
a=int(input('Temperature  Celsius'))
f=(a*9/5)+32
print('Temperature in Fahrenheit',f)
# Out:
# Temperature  Celsius30
# Temperature in Fahrenheit 86.0

# %%
#Salary Slip

# %%
s=int(input('enter the salary  '))
hra=0.2*s
da=0.1*s
net_salary=s+hra+da
print('net salary',net_salary)
# Out:
# enter the salary20000
# net salary 26000.0

# %%
#Simple Interest

# %%
s=int(input('enter the principle ammount'))
r=int(input('enter the rate of interest'))
t=int(input('enter the time '))
si=s*r*t/100
print('simple interest',si)
# Out:
# enter the principle ammount10000
# enter the rate of interest5
# enter the time 2
# simple interest 1000.0

# %%
#Time Conversion
#Write a program to convert total minutes into hours and minutes.
#Sample Input:
Enter total minutes: 130
Sample Output:
2 hours and 10 minutes

# %%
min=int(input('enter the minutes'))
h=min//60
m=min%60
print(h,'hours and',m,'minutes')
# Out:
# enter the minutes130
# 2 hours and 10 minutes

# %% [markdown]
# 6. BMI Calculator
# Write a program to calculate the Body Mass Index (BMI) using the formula: BMI
# weight(kg) / (height(m) × height(m))
# Sample Input:
# Weight: 60
# Height: 1.65
# Sample Output:
# BMI = 22.04

# %%
m=float(input('ente the body mass'))
w=float(input('enter the height'))
bmi = m/w**2
print( "BMI=",bmi)
# Out:
# ente the body mass60
# enter the height1.65
# BMI= 22.03856749311295

# %% [markdown]
# 7. Discount Calculation
# A store offers a 10% discount on every item. Write a program that takes the original price
# and prints the discounted price.
# Sample Input:
# Original price: 1200
# Sample Output:
# Discounted Price: 1080.0

# %%
o=int(input('orginal price'))
s=0.1*o
h=o-s
print('discounted price',h)
# Out:
# orginal price1200
# discounted price 1080.0

# %% [markdown]
# 8. Area of a Triangle (Using Heron’s Formula)
# A land surveyor wants to calculate the area of an irregular triangular plot.
# Write a Python program to find the area of a triangle when all three sides are known,
# using Heron’s formula:
# 𝑠 =
# 𝑎 + 𝑏 + 𝑐
# 2
# Area = √𝑠(𝑠 − 𝑎)(𝑠 − 𝑏)(𝑠 − 𝑐)
# Sample Input:
# Enter side a: 5
# Enter side b: 6
# Enter side c: 7
# Sample Output:
# Area of the triangle: 14.70

# %%
s1=int(input('enter the side 1:'))
s2=int(input('enter the side 2:'))
s3=int(input('enter the side 3:'))
s=(s1+s2+s3)/2
import math
area = math.sqrt(s*(s-s1)*(s-s2)*(s-s3))
print('area of triangle',area)
# Out:
# enter the side 1:5
# enter the side 2:6
# enter the side 3:7
# area of triangle 14.696938456699069

# %% [markdown]
# . Paint Cost Estimator
# A painter charges ₹25 per square meter. Write a program to calculate the total cost to
# paint a rectangular wall. The wall has length and height, and there are two windows each
# measuring 1.5m × 1.2m that should not be painted. Find the total area to be painted and
# its total cost.
# Sample Input:
# Enter wall length (in meters): 12
# Enter wall height (in meters): 8
# Sample Output:
# Total area to be painted: 92.4 sq.m
# Total painting cost: ₹2310.0

# %%
ta=int(input('ENTER THE WALL LENTH (IN METER)' ))
th=int(input('ENTER THE WALL HEIGHT( IN METER)'))
W=1.5*1.2
AREA=ta*th
u=AREA-W
y=u*25
print('TOTAL AREA TO BE PAINTED',u)
print('TOTAL PAINTING COST',y)
# Out:
# ENTER THE WALL LENTH (IN METER)12
# ENTER THE WALL HEIGHT( IN METER)8
# TOTAL AREA TO BE PAINTED 94.2
# TOTAL PAINTING COST 2355.0

# %% [markdown]
# 10. Electricity Bill Calculator
# An electricity board charges consumers based on unit consumption. The rate per unit is
# ₹5.2. Additionally, there is a fixed charge of ₹100 on every bill. Write a Python program
# that takes the number of units consumed and calculates the total bill amount.
# Sample Input:
# Enter number of units consumed: 250
# Sample Output:
# Electricity Bill: ₹1400.0

# %%
e=int(input('enter the number of units consumed'))
f=e*5.2
r=100
a=f+r
print('electricity bill',a)
# Out:
# enter the number of units consumed250
# electricity bill 1400.0
